# %% [markdown]
# # Обучение многослойной сети [GPU]

# %% [markdown]
# Для агрегатора магазинов одежды нужно сделать классификатор на 10 классов. Каждый класс будет отвечать за определённую категорию товаров и отражён на сайте агрегатора:
#
# Label	Description
# 0	    T-shirt/top
# 1	    Trouser
# 2	    Pullover
# 3	    Dress
# 4	    Coat
# 5	    Sandal
# 6	    Shirt
# 7	    Sneaker
# 8	    Bag
# 9	    Ankle boot
#
# Мы будем работать с изображениями, потому что описания товаров могут содержать некорректную информацию, их может быть слишком много и причём на разных языках.
# На входе модель будет получать чёрно-белую фотографию товара.
#
# Задача построить и обучить свёрточную нейронную сеть на наборе данных с предметами одежды.
# При работе с нейронными сетями требуются большие вычислительные мощности. Поэтому модель будет запускаться на сервере.
#
# **Описание данных**
# Данные находятся в датасете `fashion-mnist`.  Размер обучающей выборки: (60000, 28, 28), размер тестовой выборки: (10000, 28, 28).

# %%
# Необходимые импорты
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
import numpy as np


# Загружаем обучающую выборку
def load_train(path):
    # загрузка признаков
    features_train = np.load(path + 'train_features.npy')
    # заргузка целевого признака
    target_train = np.load(path + 'train_target.npy')
    # приведение изображений в двумерную таблицу и в диапазон [0, 1]
    features_train = features_train.reshape(features_train.shape[0], 28 * 28) / 255.
    # результат: возвращение загруженных данных тестовой выборки (тестовые данные сервер грузит сам)
    return features_train, target_train

# Создаём модель
def create_model(input_shape):
    # инициализация модели
    model = Sequential()
    # добавление слоёв в модель
    model.add(Dense(units=800, input_shape=input_shape, activation="relu"))
    model.add(Dense(units=400, activation="relu"))
    model.add(Dense(units=10, activation='softmax'))
    # подготовка модели к обучению
    model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['acc'])
    # результат: возвращение настроенной модели
    return model

# Обучаем модель
def train_model(model, train_data, test_data, batch_size=40, epochs=5,
               steps_per_epoch=None, validation_steps=None):
    # назначение тренировочных и тестовых данных
    features_train, target_train = train_data
    features_test, target_test = test_data
    # обучение модели
    model.fit(features_train, target_train, 
              validation_data=(features_test, target_test),
              batch_size=batch_size, epochs=epochs,
              steps_per_epoch=steps_per_epoch,
              validation_steps=validation_steps,
              verbose=2, shuffle=True)
    # результат: возвращение обученной модели
    return model

# %% [raw]
# 2024-07-11 05:15:12.309139: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2024-07-11 05:15:12.311125: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# 2024-07-11 05:15:13.294473: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2024-07-11 05:15:13.301302: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:8b:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2024-07-11 05:15:13.301381: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2024-07-11 05:15:13.301433: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2024-07-11 05:15:13.303580: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2024-07-11 05:15:13.303969: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2024-07-11 05:15:13.306497: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2024-07-11 05:15:13.308381: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2024-07-11 05:15:13.308428: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2024-07-11 05:15:13.311750: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# Using TensorFlow backend.
# 2024-07-11 05:15:14.084391: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2024-07-11 05:15:14.091585: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 1999990000 Hz
# 2024-07-11 05:15:14.092315: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x59b6680 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2024-07-11 05:15:14.092343: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2024-07-11 05:15:14.234462: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5191be0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-07-11 05:15:14.234539: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-PCIE-32GB, Compute Capability 7.0
# 2024-07-11 05:15:14.236453: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:8b:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2024-07-11 05:15:14.236570: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2024-07-11 05:15:14.236587: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2024-07-11 05:15:14.236616: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2024-07-11 05:15:14.236634: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2024-07-11 05:15:14.236650: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2024-07-11 05:15:14.236665: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2024-07-11 05:15:14.236676: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2024-07-11 05:15:14.239880: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2024-07-11 05:15:14.239975: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2024-07-11 05:15:14.570507: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1096] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-07-11 05:15:14.570574: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102]      0
# 2024-07-11 05:15:14.570583: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] 0:   N
# 2024-07-11 05:15:14.573889: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-07-11 05:15:14.573950: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1241] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10240 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:8b:00.0, compute capability: 7.0)
# <class 'tensorflow.python.keras.engine.sequential.Sequential'>
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/5
# 2024-07-11 05:15:15.809886: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 60000/60000 - 5s - loss: 0.7052 - acc: 0.7721 - val_loss: 0.5415 - val_acc: 0.8186
# Epoch 2/5
# 60000/60000 - 4s - loss: 0.4819 - acc: 0.8328 - val_loss: 0.4647 - val_acc: 0.8393
# Epoch 3/5
# 60000/60000 - 4s - loss: 0.4392 - acc: 0.8472 - val_loss: 0.4656 - val_acc: 0.8329
# Epoch 4/5
# 60000/60000 - 4s - loss: 0.4110 - acc: 0.8563 - val_loss: 0.4456 - val_acc: 0.8423
# Epoch 5/5
# 60000/60000 - 4s - loss: 0.3917 - acc: 0.8636 - val_loss: 0.4123 - val_acc: 0.8560
# 10000/10000 - 1s - loss: 0.4123 - acc: 0.8560

# %% [markdown]
# **Вывод.** Модель обучена. Метрика `accuracy` на тренировочной выборке 0.8636, на валидационной 0.8560, на тестовой 0.8560. Модель пригодна к использованию.
